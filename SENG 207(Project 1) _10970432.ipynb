# %% [markdown]
# ### Name: Tawiah Yemo-Booba
#
# ### ID:10970432
#
# ### Class : Biomedical Engineering
#
#
# ### __Programming Project__
# ---

# %%
#importing libraries
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as pd

# %%
import pandas as pd

# %% [markdown]
# To display the DataFrame for this project.

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ## Null Count
# ---
# _Null count_ refers to the number of missing values in a particular column in a DataFrame.
# To determine the number of missing values in each column, we use:

# %%
null_counts = df.isnull().sum()

# %%
print(null_counts)
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# There are ten null count values.
#
# To determine the location of the null values:

# %%
# Find the locations of null values in this DataFrame
import numpy as np
null_locations = np.where(df.isnull())

# Print the locations of null values
for row, col in zip(null_locations[0], null_locations[1]):
    print(f"Null value at row {row} and column {df.columns[col]}")
# Out:
# Null value at row 2 and column pH
# Null value at row 10 and column total sulfur dioxide
# Null value at row 23 and column citric acid
# Null value at row 179 and column free sulfur dioxide
# Null value at row 581 and column quality
# Null value at row 1113 and column chlorides
# Null value at row 1231 and column density
# Null value at row 1584 and column chlorides
# Null value at row 1585 and column chlorides
# Null value at row 1595 and column fixed acidity

# %% [markdown]
# ## Duplicate Values
# ---
# _Duplicates_ in a DataFrame refers to a row that have identical values in all columns as another row in the same DataFrame.
#
# Duplicate rows can occur due to errors in data entry, data merging, or data extraction.

# %% [markdown]
# To determine the number of duplicates and their locations:

# %%
# Find the number of duplicates
duplicates=df.duplicated()
print(duplicates)
number_duplicates = df.duplicated().sum()

# Print the number of duplicates
print(f"There are {number_duplicates} duplicate rows in the DataFrame.")

# Find the duplicate rows
duplicate_rows = df[df.duplicated()]

# Print the duplicate rows
print("Duplicate rows in the DataFrame:")
print(duplicate_rows)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool
# There are 0 duplicate rows in the DataFrame.
# Duplicate rows in the DataFrame:
# Empty DataFrame
# Columns: [ID, fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %% [markdown]
# ## Pre-processing DataFrame
# ---
# To pre-process data to get rid of all null values and duplicates:

# %%
# Print the original DataFrame
print('Original DataFrame:\n',df)

# Remove null count values
# Remove any rows with missing values
df = df.dropna()

# Print the DataFrame without null count values
print('DataFrame without null count values:\n', df)
# Out:
# Original DataFrame:
#          ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
# ...

# %%
#Print the original DataFrame
print('Original DataFrame:\n',df)


# Remove duplicate rows
df = df.drop_duplicates()

# Print the DataFrame without duplicates
print('DataFrame without duplicates:\n',df)
# Out:
# Original DataFrame:
#          ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
# ...

# %% [markdown]
# This analysis shows there are no duplicates.

# %% [markdown]
# ## Using the Dropna method for Null values
# ---
# The reason for using the Dropna module is that the 'dropna()' method in Pandas allows to remove missing values from a DataFrame by either dropping rows or columns that contain any missing values or only those that contain a certain threshold of missing values. This method is verysimple, effective, flexible and can be customized to fit specific needs.

# %% [markdown]
# ## Statistical Inferences of Dataset (df)
# ---

# %%
df = df.dropna()
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %% [markdown]
# ## Statistical inferences of individual columns
# ---

# %% [markdown]
# For the column: fixed acidity

# %%
df['fixed acidity'].describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %% [markdown]
# For the column: volatile acidity

# %%
df['volatile acidity'].describe()
# Out:
# count    1591.000000
# mean        0.527681
# std         0.179045
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %% [markdown]
# For the column:citric acid

# %%
df['citric acid'].describe()
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %% [markdown]
# For the column: residual sugar

# %%
df['residual sugar'].describe()
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %% [markdown]
# For the column: chlorides

# %%
df['chlorides'].describe()
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %% [markdown]
# For the column:free sulphur dioxide

# %%
df['free sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %% [markdown]
# For the column: total sulfur dioxide

# %%
df['total sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       46.498429
# std        32.998659
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %% [markdown]
# For the column: density

# %%
df['density'].describe()
# Out:
# count    1591.000000
# mean        0.996747
# std         0.001889
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997845
# max         1.003690
# Name: density, dtype: float64

# %% [markdown]
# For the column:pH

# %%
df['pH'].describe()
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %% [markdown]
# For the column: sulphates

# %%
df['sulphates'].describe()
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %% [markdown]
# For the column: alcohol

# %%
df['alcohol'].describe()
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %% [markdown]
# For the column: quality

# %%
df['quality'].describe()
# Out:
# count    1591.000000
# mean        5.637964
# std         0.807772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %% [markdown]
# ### Hidden Inferences
# ---
# Hidden inferences in Jupyter Dataframe refer to the truncated rows and columns in large datasets to make them more manageable for viewing. The default format is displaying the first and last five rows and hiding those in the middle. Hidden inferences help to make data analysis and manipulation more efficient and user-friendly.Some hidden inferences in Jupyter are; column, index, missing values, operations etc.

# %% [markdown]
# To display the whole DataFrame, we use:

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
#displaying the dataset
display(df)
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00            1.90
# 1        2            7.8             0.880         0.00            2.60
# 3        4           11.2             0.280         0.56            1.90
# 4        5            7.4             0.700         0.00            1.90
# 5        6            7.4             0.660         0.00            1.80
# 6        7            7.9             0.600         0.06            1.60
# 7        8            7.3             0.650         0.00            1.20
# 8        9            7.8             0.580         0.02            2.00
# 9       10            7.5             0.500         0.36            6.10
# 11      12            7.5             0.500         0.36            6.10
# 12      13            5.6             0.615         0.00            1.60
# 13      14            7.8             0.610         0.29            1.60
# ...

# %% [markdown]
# ### Showing Data Correlation Among The Columns
# ---

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#to calculate the correlation matrix
#to plot the heatmap
col = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']
cor= df[col].corr()
fig,ax = plt.subplots(figsize=(11, 6)) 
heatmap = sns.heatmap(cor, annot=True, cmap='viridis',ax=ax)
heatmap.set_xticklabels(heatmap.get_xticklabels())
# Out:
# [Text(0.5, 0, 'fixed acidity'),
#  Text(1.5, 0, 'volatile acidity'),
#  Text(2.5, 0, 'citric acid'),
#  Text(3.5, 0, 'residual sugar'),
#  Text(4.5, 0, 'chlorides'),
#  Text(5.5, 0, 'free sulfur dioxide'),
#  Text(6.5, 0, 'total sulfur dioxide'),
#  Text(7.5, 0, 'density'),
#  Text(8.5, 0, 'pH'),
#  Text(9.5, 0, 'sulphates'),
#  Text(10.5, 0, 'alcohol'),
#  Text(11.5, 0, 'quality')]

# %% [markdown]
# ### Histogram And Piecharts
# ---

# %%
import seaborn as sns
histogram_plot1 = sns.histplot(data=df, x='fixed acidity')

histogram_plot1.set_title("Histogram plot for fixed acidity")
# Out:
# Text(0.5, 1.0, 'Histogram plot for fixed acidity')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
mean_1 = df['fixed acidity'].mean()


above_mean_count = df[df['fixed acidity'] > mean_1]['fixed acidity'].count()
below_mean_count = df[df['fixed acidity'] < mean_1]['fixed acidity'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['cyan', 'blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%' )
# plt.axis('equal')
plt.title('Fixed Acidity Greater than and Less than Mean')
plt.show()

# %%
histogram_plot2 = sns.histplot(data=df, x='volatile acidity')

histogram_plot2.set_title("Histogram plot for volatile acidity")
# Out:
# Text(0.5, 1.0, 'Histogram plot for volatile acidity')

# %%
import matplotlib.pyplot as plt
mean_1 = df['volatile acidity'].mean()


above_mean_count = df[df['volatile acidity'] > mean_1]['volatile acidity'].count()
below_mean_count = df[df['volatile acidity'] < mean_1]['volatile acidity'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['cyan','blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Volatile Acidity Greater than and Less than Mean')
plt.show()

# %%
histogram_plot3 = sns.histplot(data=df, x='citric acid')

histogram_plot3.set_title("Histogram plot for citric acid")
# Out:
# Text(0.5, 1.0, 'Histogram plot for citric acid')

# %%
import matplotlib.pyplot as plt
mean_1 = df['citric acid'].mean()


above_mean_count = df[df['citric acid'] > mean_1]['citric acid'].count()
below_mean_count = df[df['citric acid'] < mean_1]['citric acid'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'cyan']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Citric Acid Greater than and Less than Mean')
plt.show()

# %%
histogram_plot4 = sns.histplot(data=df, x='residual sugar')

histogram_plot4.set_title("Histogram plot for residual sugar")
# Out:
# Text(0.5, 1.0, 'Histogram plot for residual sugar')

# %%
import matplotlib.pyplot as plt
mean_1 = df['residual sugar'].mean()


above_mean_count = df[df['residual sugar'] > mean_1]['residual sugar'].count()
below_mean_count = df[df['residual sugar'] < mean_1]['residual sugar'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['cyan', 'blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Residual Sugar Greater than and Less than Mean')
plt.show()

# %%
histogram_plot5 = sns.histplot(data=df, x='chlorides')

histogram_plot5.set_title("Histogram plot for chlorides")
# Out:
# Text(0.5, 1.0, 'Histogram plot for chlorides')

# %%
import matplotlib.pyplot as plt
mean_1 = df['chlorides'].mean()


above_mean_count = df[df['chlorides'] > mean_1]['chlorides'].count()
below_mean_count = df[df['chlorides'] < mean_1]['chlorides'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['cyan', 'blue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Chlorides Greater than and Less than Mean')
plt.show()

# %%
histogram_plot6 = sns.histplot(data=df, x='free sulfur dioxide')

histogram_plot6.set_title("Histogram plot for free sulfur dioxide")
# Out:
# Text(0.5, 1.0, 'Histogram plot for free sulfur dioxide')

# %%
import matplotlib.pyplot as plt
mean_1 = df['free sulfur dioxide'].mean()


above_mean_count = df[df['free sulfur dioxide'] > mean_1]['free sulfur dioxide'].count()
below_mean_count = df[df['free sulfur dioxide'] < mean_1]['free sulfur dioxide'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'cyan']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Free Sulfur Dioxide Greater than and Less than Mean')
plt.show()

# %%
histogram_plot7 = sns.histplot(data=df, x='total sulfur dioxide')

histogram_plot7.set_title("Histogram plot for total sulfur dioxide")
# Out:
# Text(0.5, 1.0, 'Histogram plot for total sulfur dioxide')

# %%
import matplotlib.pyplot as plt
mean_1 = df['total sulfur dioxide'].mean()


above_mean_count = df[df['total sulfur dioxide'] > mean_1]['total sulfur dioxide'].count()
below_mean_count = df[df['total sulfur dioxide'] < mean_1]['total sulfur dioxide'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'cyan']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Total Sulfur Dioxide Greater than and Less than Mean')
plt.show()

# %%
histogram_plot8 = sns.histplot(data=df, x='density')

histogram_plot8.set_title("Histogram plot for density")
# Out:
# Text(0.5, 1.0, 'Histogram plot for density')

# %%
import matplotlib.pyplot as plt
mean_1 = df['density'].mean()


above_mean_count = df[df['density'] > mean_1]['density'].count()
below_mean_count = df[df['density'] < mean_1]['density'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'cyan']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Density Greater than and Less than Mean')
plt.show()

# %%
histogram_plot9 = sns.histplot(data=df, x='pH')

histogram_plot9.set_title("Histogram plot for pH")
# Out:
# Text(0.5, 1.0, 'Histogram plot for pH')

# %%
import matplotlib.pyplot as plt
mean_1 = df['pH'].mean()


above_mean_count = df[df['pH'] > mean_1]['pH'].count()
below_mean_count = df[df['pH'] < mean_1]['pH'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'cyan']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('pH Greater than and Less than Mean')
plt.show()

# %%
histogram_plot10 = sns.histplot(data=df, x='sulphates')

histogram_plot10.set_title("Histogram plot for sulphates")
# Out:
# Text(0.5, 1.0, 'Histogram plot for sulphates')

# %%
import matplotlib.pyplot as plt
mean_1 = df['sulphates'].mean()


above_mean_count = df[df['sulphates'] > mean_1]['sulphates'].count()
below_mean_count = df[df['sulphates'] < mean_1]['sulphates'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'cyan']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Sulphates Greater than and Less than Mean')
plt.show()

# %%
histogram_plot11 = sns.histplot(data=df, x='alcohol')

histogram_plot11.set_title("Histogram plot for alcohol")
# Out:
# Text(0.5, 1.0, 'Histogram plot for alcohol')

# %%
import matplotlib.pyplot as plt
mean_1 = df['alcohol'].mean()


above_mean_count = df[df['alcohol'] > mean_1]['alcohol'].count()
below_mean_count = df[df['alcohol'] < mean_1]['alcohol'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'cyan']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Alcohol Greater than and Less than Mean')
plt.show()

# %%
histogram_plot12 = sns.histplot(data=df, x='quality')

histogram_plot12.set_title("Histogram plot for quality")
# Out:
# Text(0.5, 1.0, 'Histogram plot for quality')

# %%
import matplotlib.pyplot as plt
mean_1 = df['quality'].mean()


above_mean_count = df[df['quality'] > mean_1]['quality'].count()
below_mean_count = df[df['quality'] < mean_1]['quality'].count()


labels = ['Greater than Mean', 'Less than Mean']
sizes = [above_mean_count, below_mean_count]
colors = ['blue', 'cyan']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Quality Greater than and Less than Mean')
plt.show()
